# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Find_outliers.csv')

# %%
df.shape
# Out:
# (143966, 24)

# %%
df.columns
# Out:
# Index(['listing_type', 'listing_first_date', 'days_on_market', 'dealer_city',
#        'dealer_postal_code', 'stock_type', 'vehicle_id', 'vin', 'mileage',
#        'price', 'msrp', 'model_year', 'make', 'model', 'series', 'style',
#        'certified', 'exterior_color_category', 'interior_color_category',
#        'wheelbase_from_vin', 'drivetrain_from_vin', 'engine_from_vin',
#        'transmission_from_vin', 'fuel_type_from_vin'],
#       dtype='object')

# %%
df['listing_type'].unique()
# Out:
# array(['Active', 'Sold'], dtype=object)

# %%
df['dealer_city'].unique()
# Out:
# array(['Edmonton', 'St Albert', 'Sherwood Park', 'Leduc', 'Nisku',
#        'Spruce Grove', 'Fort Saskatchewan', 'Acheson', 'Devon'],
#       dtype=object)

# %%
df['stock_type'].unique()
# Out:
# array(['USED', 'NEW'], dtype=object)

# %%
df['certified'].unique()
# Out:
# array([0, 1])

# %%
df['drivetrain_from_vin'].unique()
# Out:
# array(['RWD', 'FWD', '4WD', 'AWD'], dtype=object)

# %%
df['transmission_from_vin'].unique()
# Out:
# array(['A', 'M', '6', '7'], dtype=object)

# %%
df['transmission_from_vin'].value_counts()
# Out:
# transmission_from_vin
# A    139985
# M      3947
# 7        32
# 6         2
# Name: count, dtype: int64

# %%
df['transmission_from_vin'] = df['transmission_from_vin'].replace('7','A')

# %%
df['transmission_from_vin'] = df['transmission_from_vin'].replace('6','M')

# %%
df['transmission_from_vin'].value_counts()
# Out:
# transmission_from_vin
# A    140017
# M      3949
# Name: count, dtype: int64

# %%
df['fuel_type_from_vin'].unique()
# Out:
# array(['Gas', 'CNG', 'Diesel', 'Hybrid', 'Electric', 'PHEV', 'Hydrogen'],
#       dtype=object)

# %%
df_old = df[df['stock_type'] == 'USED']
df_new = df[df['stock_type'] == 'NEW']

# %%
df1 = df_old.copy()

# %%
x = df1.select_dtypes(include=np.number).columns

# %%
for i in x:
  print(f"Skewness of {i} is {df1[i].skew()}")
# Out:
# Skewness of days_on_market is 2.7882933127250062
# Skewness of vehicle_id is -1.272480576722119
# Skewness of mileage is 1.3548118874443096
# Skewness of price is 119.762875056208
# Skewness of msrp is 1.7655124847266703
# Skewness of model_year is -1.5238411812734836
# Skewness of certified is 8.748461728271996
# Skewness of wheelbase_from_vin is -1.3849499289262066

# %%
y = df_new.select_dtypes(include=np.number).columns
for i in y:
  print(f"Skewness of {i} is {df_new[i].skew()}")
# Out:
# Skewness of days_on_market is 2.094036655035662
# Skewness of vehicle_id is -3.775796989224313
# Skewness of mileage is 38.66840379474756
# Skewness of price is 71.01704851145425
# Skewness of msrp is 1.262565465075321
# Skewness of model_year is -5.168680622361033
# Skewness of certified is 0.0
# Skewness of wheelbase_from_vin is 0.8036860274774001

# %%
df_old
# Out:
#        listing_type listing_first_date  days_on_market dealer_city  \
# 0            Active     7/22/2024 0:00               9    Edmonton
# 1              Sold     7/20/2024 0:00               4    Edmonton
# 2            Active      6/7/2024 0:00              54    Edmonton
# 3            Active     7/21/2024 0:00              10    Edmonton
# 4              Sold     3/26/2024 0:00              38    Edmonton
# ...             ...                ...             ...         ...
# 143951         Sold     4/24/2024 0:00              55    Edmonton
# 143956         Sold     4/12/2024 0:00              72    Edmonton
# 143958         Sold     4/13/2024 0:00              67    Edmonton
# 143963         Sold      5/6/2024 0:00              22    Edmonton
# 143965         Sold     7/20/2024 0:00               4    Edmonton
#
#        dealer_postal_code stock_type  vehicle_id                vin  mileage  \
# 0                 T5S 1Y8       USED       79126  1G1FP2189HN139203   230860
# ...

# %%
df
# Out:
#        listing_type listing_first_date  days_on_market dealer_city  \
# 0            Active     7/22/2024 0:00               9    Edmonton
# 1              Sold     7/20/2024 0:00               4    Edmonton
# 2            Active      6/7/2024 0:00              54    Edmonton
# 3            Active     7/21/2024 0:00              10    Edmonton
# 4              Sold     3/26/2024 0:00              38    Edmonton
# ...             ...                ...             ...         ...
# 143961         Sold      3/5/2024 0:00              99    Edmonton
# 143962         Sold      3/5/2024 0:00              96    Edmonton
# 143963         Sold      5/6/2024 0:00              22    Edmonton
# 143964         Sold     3/20/2024 0:00              71    Edmonton
# 143965         Sold     7/20/2024 0:00               4    Edmonton
#
#        dealer_postal_code stock_type  vehicle_id                vin  mileage  \
# 0                 T5S 1Y8       USED       79126  1G1FP2189HN139203   230860
# ...
