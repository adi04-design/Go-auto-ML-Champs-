# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("Go_Auto_Dataset.csv")

# %%
df.head()
# Out:
#                              listing_id                  listing_heading  \
# 0  f5b663d2-4896-11ef-a15b-8b4423f1ff08     1987 IROC Z  350 Auto T-Tops
# 1  a9f565e6-4712-11ef-a23f-79dc25c5e601                              NaN
# 2  03d18c58-253a-11ef-8f33-8905b4a2f000  1989 Cadillac DeVille Sedan FWD
# 3  2d12630b-460e-11ee-89c4-e5b3161d4741  1989 Cadillac DeVille Sedan FWD
# 4  53a8e550-47cd-11ef-8587-f926ecb61035  1989 Camaro IROC 350 Auto T-Top
#
#   listing_type                                        listing_url  \
# 0       Active  https://www.kijiji.ca/v-cars-trucks/edmonton/1...
# 1         Sold  https://www.redlinemotors.ca/vehicle-details/1...
# 2       Active  https://www.sweetheartmotor.com/cars/used/1989...
# 3       Active  https://www.sweetheartmotor.com/cars/used/1989...
# 4       Active  https://www.kijiji.ca/v-cars-trucks/edmonton/1...
#
#   listing_first_date  days_on_market  dealer_id  \
# 0     7/22/2024 0:00               9   11152931
# ...

# %%
df.sample(10)
# Out:
#                                   listing_id  \
# 124418  63be0543-424c-11ef-8bb5-27e7a87a9d90
# 88750   f5ba1e8f-4719-46dc-b283-106b16c2efb7
# 112945  85db061a-29f3-11ef-aeac-f9373b623c21
# 39732   fb2795db-004a-11ef-b7b5-fb6bd4e2bebc
# 38433   fa9e8fd0-004a-11ef-b7b5-859581d18ba8
# 136272  b27485dc-1b02-11ef-80ce-559570f70417
# 121877  d85cdcd0-362c-11ef-81dd-1bbf2ad469ed
# 137872  8dedebe8-3a71-11ef-8cab-e737d98376c6
# 91941   fb3b6c97-004a-11ef-b7b5-9f1446172c84
# 103033  fb780028-004a-11ef-913f-d789a42f12b5
#
#                                           listing_heading listing_type  \
# 124418                      2024 Lincoln Corsair Standard       Active
# 88750   New 2024 Chevrolet Malibu LS 4dr Car Summit Wh...       Active
# 112945               2024 Honda Odyssey Black Edition FWD         Sold
# 39732   2020 Jeep Cherokee Trailhawk Elite | Class 3 T...         Sold
# 38433                              2020 Honda CR-V LX AWD         Sold
# ...

# %%
len(df.columns)
# Out:
# 46

# %%
df_x = df.copy()

# %%
df_x=df_x.drop(['listing_id'], axis=1)

# %%
df_x=df_x.drop(['listing_heading'], axis=1)

# %%
df_x=df_x.drop(['listing_url'], axis = 1)

# %%
df_x=df_x.drop( ['dealer_id'],axis = 1)

# %%
df_x=df_x.drop(['dealer_name'], axis =1)

# %%
df_x=df_x.drop( ['dealer_street'], axis = 1)

# %%
df_x=df_x.drop(['dealer_province'], axis = 1)

# %%
df_x=df_x.drop(['dealer_url'],axis =1)

# %%
df_x=df_x.drop(['dealer_email'], axis = 1)

# %%
df_x=df_x.drop(['dealer_phone'], axis = 1)

# %%
df_x=df_x.drop(['dealer_type'], axis = 1)

# %%
df_x=df_x.drop(['uvc'], axis = 1)

# %%
df_x=df_x.drop(['has_leather'], axis = 1)

# %%
df_x=df_x.drop(['has_navigation'], axis = 1)

# %%
df_x=df_x.drop(['exterior_color'], axis = 1)

# %%
df_x=df_x.drop(['interior_color'], axis = 1)

# %%
df_x=df_x.drop(['price_analysis'], axis = 1)

# %%
df_x=df_x.drop(['number_price_changes'], axis = 1)

# %%
df_x=df_x.drop(['price_history_delimited'], axis =1)

# %%
df_x=df_x.drop(['distance_to_dealer'], axis = 1)

# %%
df_x=df_x.drop(['location_score'], axis = 1)

# %%
df_x.columns
# Out:
# Index(['listing_type', 'listing_first_date', 'days_on_market', 'dealer_city',
#        'dealer_postal_code', 'stock_type', 'vehicle_id', 'vin', 'mileage',
#        'price', 'msrp', 'model_year', 'make', 'model', 'series', 'style',
#        'certified', 'exterior_color_category', 'interior_color_category',
#        'wheelbase_from_vin', 'drivetrain_from_vin', 'engine_from_vin',
#        'transmission_from_vin', 'fuel_type_from_vin', 'listing_dropoff_date'],
#       dtype='object')

# %%
df_x
# Out:
#        listing_type listing_first_date  days_on_market dealer_city  \
# 0            Active     7/22/2024 0:00               9    Edmonton
# 1              Sold     7/20/2024 0:00               4    Edmonton
# 2            Active      6/7/2024 0:00              54    Edmonton
# 3            Active     8/28/2023 0:00             338    Edmonton
# 4            Active     7/21/2024 0:00              10    Edmonton
# ...             ...                ...             ...         ...
# 145109         Sold      3/5/2024 0:00              99    Edmonton
# 145110         Sold      3/5/2024 0:00              96    Edmonton
# 145111         Sold      5/6/2024 0:00              22    Edmonton
# 145112         Sold     3/20/2024 0:00              71    Edmonton
# 145113         Sold     7/20/2024 0:00               4    Edmonton
#
#        dealer_postal_code stock_type  vehicle_id                vin  mileage  \
# 0                 T5S 1Y8       USED       79126  1G1FP2189HN139203   230860
# ...

# %%
df_x.sample(10)
# Out:
#        listing_type listing_first_date  days_on_market    dealer_city  \
# 140464       Active     7/16/2024 0:00              15  Sherwood Park
# 78149          Sold     5/25/2024 0:00              43       Edmonton
# 67528          Sold     4/13/2024 0:00              98       Edmonton
# 130517       Active     4/17/2024 0:00             105  Sherwood Park
# 77945        Active     7/16/2024 0:00              15       Edmonton
# 122476         Sold      6/7/2024 0:00              31       Edmonton
# 122736         Sold      5/8/2024 0:00              14       Edmonton
# 127445         Sold     4/20/2024 0:00              25       Edmonton
# 86006        Active     6/10/2024 0:00              51       Edmonton
# 87316          Sold     5/11/2024 0:00              34       Edmonton
#
#        dealer_postal_code stock_type  vehicle_id                vin  mileage  \
# 140464            T8H 0R5       USED      582211  5TFLA5EC2RX024248    10375
# ...

# %%
label = df_x['listing_type'].value_counts().plot.pie(autopct='%0.2f')
plt.title('Listing Type Distribution')
plt.show()

# %%
df_x['listing_first_date'] = pd.to_datetime(df_x['listing_first_date'])
df_x['listing_year_2023'] = df_x['listing_first_date'].dt.year == 2023
df_x['listing_year_2024'] = df_x['listing_first_date'].dt.year == 2024

# %%
plt.pie([df_x['listing_year_2023'].sum(),df_x['listing_year_2024'].sum()],labels= ('2023','2024'),autopct='%0.2f')
plt.title('Listing Year Distribution')
plt.show()

# %%
df_x.columns
# Out:
# Index(['listing_type', 'listing_first_date', 'days_on_market', 'dealer_city',
#        'dealer_postal_code', 'stock_type', 'vehicle_id', 'vin', 'mileage',
#        'price', 'msrp', 'model_year', 'make', 'model', 'series', 'style',
#        'certified', 'exterior_color_category', 'interior_color_category',
#        'wheelbase_from_vin', 'drivetrain_from_vin', 'engine_from_vin',
#        'transmission_from_vin', 'fuel_type_from_vin', 'listing_dropoff_date',
#        'listing_year_2023', 'listing_year_2024'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 3))
plt.hist(df_x['days_on_market'],edgecolor='black', bins=20)
plt.xticks(rotation=90)
plt.xlabel('Days on Market')
plt.ylabel('Frequency')
plt.title('Distribution of Days on Market')
plt.show()

# %%
df_x['make'].unique()
# Out:
# array(['Chevrolet', 'Chrysler', 'Cadillac', 'Volkswagen', 'Dodge',
#        'Mazda', 'Toyota', 'Mercury', 'Pontiac', 'BMW', 'Honda', 'Jeep',
#        'Lexus', 'Acura', 'GMC', 'Jaguar', 'Ford', 'Mercedes-Benz',
#        'Nissan', 'Subaru', 'Porsche', 'Buick', 'Infiniti', 'Audi', 'Kia',
#        'Saturn', 'Volvo', 'Hummer', 'Mitsubishi', 'Suzuki', 'Hyundai',
#        'Lincoln', 'Land Rover', 'Mini', 'Smart', 'Scion', 'Fiat', 'Ram',
#        'Tesla', 'Maserati', 'Alfa Romeo', 'Genesis', 'Polestar', 'Fisker',
#        'Rivian'], dtype=object)

# %%
x = df_x[(df_x['days_on_market'] == 1) & (df_x['listing_type'] == 'Sold')].loc[:, ['make','model','model_year','price']]['make'].value_counts()
plt.bar(x.index, x.values)
plt.xticks(rotation=90)
plt.xlabel('Make')
plt.ylabel('Frequency')
plt.title('Vehicles which got sold on 1st day')
plt.show()

# %%
x = df_x[(df_x['days_on_market'] < 10) & (df_x['listing_type'] == 'Sold')].loc[:, ['make','model','model_year','price']]['make'].value_counts()
plt.figure(figsize=(10, 5))
plt.bar(x.index, x.values)
plt.xticks(rotation=90)
plt.xlabel('Make')
plt.ylabel('Frequency')
plt.title('Vehicles which got sold within 10 days')
plt.show()

# %%
sns.barplot((df_x['dealer_city'].value_counts()))
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Edmonton'),
#   Text(1, 0, 'Sherwood Park'),
#   Text(2, 0, 'Leduc'),
#   Text(3, 0, 'St Albert'),
#   Text(4, 0, 'Spruce Grove'),
#   Text(5, 0, 'Fort Saskatchewan'),
#   Text(6, 0, 'Devon'),
#   Text(7, 0, 'Acheson'),
#   Text(8, 0, 'Nisku')])

# %%
plt.figure(figsize=(40, 5))
sns.barplot(df_x['dealer_postal_code'].value_counts())
plt.xticks(rotation=90)
plt.show()

# %%
df_x[(df_x['dealer_postal_code']== 'T5V 0C3') & (df_x['listing_type'] == 'Sold') & (df_x['make'] == 'Toyota') & (df_x['days_on_market'] == 1)]
# Out:
#       listing_type listing_first_date  days_on_market dealer_city  \
# 10327         Sold         2024-06-19               1    Edmonton
# 10328         Sold         2024-07-10               1    Edmonton
# 13901         Sold         2024-06-20               1    Edmonton
# 19526         Sold         2024-06-20               1    Edmonton
# 26103         Sold         2024-06-20               1    Edmonton
# 26195         Sold         2024-06-20               1    Edmonton
# 34093         Sold         2024-06-20               1    Edmonton
# 34266         Sold         2024-07-26               1    Edmonton
# 34322         Sold         2024-07-20               1    Edmonton
# 34326         Sold         2024-06-20               1    Edmonton
# 43283         Sold         2024-07-20               1    Edmonton
# 53780         Sold         2024-07-20               1    Edmonton
# 54086         Sold         2024-06-20               1    Edmonton
# ...

# %%
(df_x['stock_type'].value_counts()).plot.pie(autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df_x.columns
# Out:
# Index(['listing_type', 'listing_first_date', 'days_on_market', 'dealer_city',
#        'dealer_postal_code', 'stock_type', 'vehicle_id', 'vin', 'mileage',
#        'price', 'msrp', 'model_year', 'make', 'model', 'series', 'style',
#        'certified', 'exterior_color_category', 'interior_color_category',
#        'wheelbase_from_vin', 'drivetrain_from_vin', 'engine_from_vin',
#        'transmission_from_vin', 'fuel_type_from_vin', 'listing_dropoff_date',
#        'listing_year_2023', 'listing_year_2024'],
#       dtype='object')

# %%
plt.hist(df_x['mileage'],edgecolor = 'black',bins = 30)
plt.xlabel('Mileage')
plt.ylabel('Frequency')
plt.title('Mileage Distribution')
plt.show()

# %%
df_x[df['mileage']<=32000].loc[:,['mileage']]
# Out:
#         mileage
# 6         21364
# 33        26000
# 34        26000
# 68        23000
# 132       31169
# ...         ...
# 145109       30
# 145110       30
# 145111     2454
# 145112     2454
# 145113     9333
#
# [82712 rows x 1 columns]

# %%
(df_x['model_year'].value_counts()).plot.bar()
# Out:
# <Axes: xlabel='model_year'>

# %%
df_x[df_x['model_year'] == 1987].loc[:,['make','model','style','series','model_year','price','listing_type']]
# Out:
#         make   model     style    series  model_year  price listing_type
# 0  Chevrolet  Camaro  2D Coupe  Iroc Z28        1987  11500       Active

# %%
df_x['make'].unique()
# Out:
# array(['Chevrolet', 'Chrysler', 'Cadillac', 'Volkswagen', 'Dodge',
#        'Mazda', 'Toyota', 'Mercury', 'Pontiac', 'BMW', 'Honda', 'Jeep',
#        'Lexus', 'Acura', 'GMC', 'Jaguar', 'Ford', 'Mercedes-Benz',
#        'Nissan', 'Subaru', 'Porsche', 'Buick', 'Infiniti', 'Audi', 'Kia',
#        'Saturn', 'Volvo', 'Hummer', 'Mitsubishi', 'Suzuki', 'Hyundai',
#        'Lincoln', 'Land Rover', 'Mini', 'Smart', 'Scion', 'Fiat', 'Ram',
#        'Tesla', 'Maserati', 'Alfa Romeo', 'Genesis', 'Polestar', 'Fisker',
#        'Rivian'], dtype=object)

# %%
plt.figure(figsize=(15, 5))
df_x['make'].value_counts().plot.bar()
plt.xticks(rotation=90)
plt.xlabel('Make')
plt.ylabel('Frequency')
plt.title('Make Distribution')
plt.show()

# %%
df_x['model'].value_counts()
# Out:
# model
# F150               6596
# 1500               5309
# Sierra 1500        4694
# Silverado 1500     3959
# Rogue              3412
#                    ...
# Tercel                1
# B9 Tribeca            1
# Sky                   1
# Aura                  1
# C/K3500 Classic       1
# Name: count, Length: 702, dtype: int64

# %%
df_x['series'].value_counts()
# Out:
# series
# XLT                     4800
# Sport                   4716
# Limited                 3907
# LT                      3025
# Denali                  2970
#                         ...
# WRX Raiu Edition           1
# S450                       1
# Signature Diesel           1
# R575                       1
# Recharge Ultimate 6P       1
# Name: count, Length: 1630, dtype: int64

# %%
df_x[df_x['series']=='C300'].loc[:,['make']]
# Out:
#                  make
# 1283    Mercedes-Benz
# 2220    Mercedes-Benz
# 2932    Mercedes-Benz
# 2933    Mercedes-Benz
# 2934    Mercedes-Benz
# ...               ...
# 126317  Mercedes-Benz
# 126318  Mercedes-Benz
# 126319  Mercedes-Benz
# 126320  Mercedes-Benz
# 126321  Mercedes-Benz
#
# [345 rows x 1 columns]

# %%
len(df_x['style'].unique())
# Out:
# 664

# %%
df_x['style'].value_counts()
# Out:
# style
# 4D Utility AWD        34601
# Crew Cab SWB 4WD      16876
# 4D Utility 4WD        15096
# 4D Utility            14045
# 4D Sedan at            5922
#                       ...
# 4D Sedan 2.0 AWD          1
# 4D Sedan at w/Lux         1
# 5D Hbk 6sp w/Lux          1
# 4D Utility 2WD 5sp        1
# 4D Utility eAWD           1
# Name: count, Length: 664, dtype: int64

# %%
df_x['certified'].value_counts().plot.pie(autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df_x.columns
# Out:
# Index(['listing_type', 'listing_first_date', 'days_on_market', 'dealer_city',
#        'dealer_postal_code', 'stock_type', 'vehicle_id', 'vin', 'mileage',
#        'price', 'msrp', 'model_year', 'make', 'model', 'series', 'style',
#        'certified', 'exterior_color_category', 'interior_color_category',
#        'wheelbase_from_vin', 'drivetrain_from_vin', 'engine_from_vin',
#        'transmission_from_vin', 'fuel_type_from_vin', 'listing_dropoff_date',
#        'listing_year_2023', 'listing_year_2024'],
#       dtype='object')

# %%
df_x['exterior_color_category'].value_counts()
# Out:
# exterior_color_category
# white               33418
# black               32965
# blue                11657
# gray                 9548
# red                  7961
#                     ...
# gray,white,red          1
# blue,gray,silver        1
# gray,gold,silver        1
# gold,black              1
# yellow,black            1
# Name: count, Length: 81, dtype: int64

# %%
df_x['interior_color_category'].value_counts()
# Out:
# interior_color_category
# black                     69560
# gray                       6758
# brown                      3194
# brown,black                2037
# gray,black                 1311
# red                        1004
# red,black                   794
# white                       350
# gray,white,brown,black      318
# gray,white,brown            192
# gray,brown,black            175
# white,brown                 116
# brown,red,black              97
# gray,brown                   88
# gray,white,black             82
# gray,white                   56
# other                        52
# white,black                  40
# gray,red                     39
# other,red                    21
# other,gray                   12
# white,brown,black             9
# other,gray,brown              7
# brown,red                     6
# other,gray,white              5
# other,brown                   3
# other,gray,white,brown        2
# other,gray,white,black        2
# ...

# %%
df_x['interior_color_category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='interior_color_category'>

# %%
df_x['drivetrain_from_vin'].unique()
# Out:
# array(['RWD', 'FWD', '4WD', 'AWD'], dtype=object)

# %%
df_x['drivetrain_from_vin'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='drivetrain_from_vin'>

# %%
len(df_x['engine_from_vin'].unique())
# Out:
# 974

# %%
df_x['transmission_from_vin'].unique()
# Out:
# array(['A', 'M', '6', '7'], dtype=object)

# %%
df_x['transmission_from_vin'].value_counts()
# Out:
# transmission_from_vin
# A    141105
# M      3975
# 7        32
# 6         2
# Name: count, dtype: int64

# %%
df_x['transmission_from_vin'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='transmission_from_vin'>

# %%
df_x['fuel_type_from_vin'].unique()
# Out:
# array(['Gas', 'CNG', 'Diesel', 'Hybrid', 'Electric', 'PHEV', 'Hydrogen'],
#       dtype=object)

# %%
df_x['fuel_type_from_vin'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='fuel_type_from_vin'>

# %%
df_x.columns
# Out:
# Index(['listing_type', 'listing_first_date', 'days_on_market', 'dealer_city',
#        'dealer_postal_code', 'stock_type', 'vehicle_id', 'vin', 'mileage',
#        'price', 'msrp', 'model_year', 'make', 'model', 'series', 'style',
#        'certified', 'exterior_color_category', 'interior_color_category',
#        'wheelbase_from_vin', 'drivetrain_from_vin', 'engine_from_vin',
#        'transmission_from_vin', 'fuel_type_from_vin', 'listing_dropoff_date',
#        'listing_year_2023', 'listing_year_2024'],
#       dtype='object')

# %%
df_x = df_x.drop(['listing_year_2023','listing_year_2024'],axis = 1)

# %%
df_x.columns
# Out:
# Index(['listing_type', 'listing_first_date', 'days_on_market', 'dealer_city',
#        'dealer_postal_code', 'stock_type', 'vehicle_id', 'vin', 'mileage',
#        'price', 'msrp', 'model_year', 'make', 'model', 'series', 'style',
#        'certified', 'exterior_color_category', 'interior_color_category',
#        'wheelbase_from_vin', 'drivetrain_from_vin', 'engine_from_vin',
#        'transmission_from_vin', 'fuel_type_from_vin', 'listing_dropoff_date'],
#       dtype='object')

# %%
df_x
# Out:
#        listing_type listing_first_date  days_on_market dealer_city  \
# 0            Active         2024-07-22               9    Edmonton
# 1              Sold         2024-07-20               4    Edmonton
# 2            Active         2024-06-07              54    Edmonton
# 3            Active         2023-08-28             338    Edmonton
# 4            Active         2024-07-21              10    Edmonton
# ...             ...                ...             ...         ...
# 145109         Sold         2024-03-05              99    Edmonton
# 145110         Sold         2024-03-05              96    Edmonton
# 145111         Sold         2024-05-06              22    Edmonton
# 145112         Sold         2024-03-20              71    Edmonton
# 145113         Sold         2024-07-20               4    Edmonton
#
#        dealer_postal_code stock_type  vehicle_id                vin  mileage  \
# 0                 T5S 1Y8       USED       79126  1G1FP2189HN139203   230860
# ...

# %%
df_x['listing_dropoff_date'] = pd.to_datetime(df_x['listing_dropoff_date'])

# %%
df_x
# Out:
#        listing_type listing_first_date  days_on_market dealer_city  \
# 0            Active         2024-07-22               9    Edmonton
# 1              Sold         2024-07-20               4    Edmonton
# 2            Active         2024-06-07              54    Edmonton
# 3            Active         2023-08-28             338    Edmonton
# 4            Active         2024-07-21              10    Edmonton
# ...             ...                ...             ...         ...
# 145109         Sold         2024-03-05              99    Edmonton
# 145110         Sold         2024-03-05              96    Edmonton
# 145111         Sold         2024-05-06              22    Edmonton
# 145112         Sold         2024-03-20              71    Edmonton
# 145113         Sold         2024-07-20               4    Edmonton
#
#        dealer_postal_code stock_type  vehicle_id                vin  mileage  \
# 0                 T5S 1Y8       USED       79126  1G1FP2189HN139203   230860
# ...

# %%
df_x.to_csv('Featured_Go_Auto_dataset.csv')

# %%
df_x.hist(figsize=(12,12),density = True,bins = 20,edgecolor = 'black')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
