# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_x = pd.read_csv('Go_Auto_Dataset.csv')

# %%
df_x.columns
# Out:
# Index(['listing_id', 'listing_heading', 'listing_type', 'listing_url',
#        'listing_first_date', 'days_on_market', 'dealer_id', 'dealer_name',
#        'dealer_street', 'dealer_city', 'dealer_province', 'dealer_postal_code',
#        'dealer_url', 'dealer_email', 'dealer_phone', 'dealer_type',
#        'stock_type', 'vehicle_id', 'vin', 'uvc', 'mileage', 'price', 'msrp',
#        'model_year', 'make', 'model', 'series', 'style', 'certified',
#        'has_leather', 'has_navigation', 'exterior_color',
#        'exterior_color_category', 'interior_color', 'interior_color_category',
#        'price_analysis', 'wheelbase_from_vin', 'drivetrain_from_vin',
#        'engine_from_vin', 'transmission_from_vin', 'fuel_type_from_vin',
#        'number_price_changes', 'price_history_delimited', 'distance_to_dealer',
#        'location_score', 'listing_dropoff_date'],
#       dtype='object')

# %%
columns = ['listing_id','listing_type','listing_first_date','days_on_market',
           'dealer_id','dealer_city','dealer_postal_code','stock_type','vehicle_id',
           'vin','mileage', 'price', 'msrp',
           'model_year', 'make', 'model', 'series', 'style', 'certified',
           'has_leather',
           'exterior_color_category','interior_color_category',
           'wheelbase_from_vin', 'drivetrain_from_vin',
           'engine_from_vin', 'transmission_from_vin', 'fuel_type_from_vin',
           'number_price_changes', 'price_history_delimited',
           'location_score', 'listing_dropoff_date']

# %%
df = df_x[columns]

# %%
df.dtypes
# Out:
# listing_id                  object
# listing_type                object
# listing_first_date          object
# days_on_market               int64
# dealer_id                    int64
# dealer_city                 object
# dealer_postal_code          object
# stock_type                  object
# vehicle_id                   int64
# vin                         object
# mileage                      int64
# price                        int64
# msrp                         int64
# model_year                   int64
# make                        object
# model                       object
# series                      object
# style                       object
# certified                    int64
# has_leather                  int64
# exterior_color_category     object
# interior_color_category     object
# wheelbase_from_vin         float64
# drivetrain_from_vin         object
# engine_from_vin             object
# transmission_from_vin       object
# fuel_type_from_vin          object
# number_price_changes         int64
# price_history_delimited     object
# location_score               int64
# listing_dropoff_date        object
# dtype: object

# %%
df.columns
# Out:
# Index(['listing_id', 'listing_type', 'listing_first_date', 'days_on_market',
#        'dealer_id', 'dealer_city', 'dealer_postal_code', 'stock_type',
#        'vehicle_id', 'vin', 'mileage', 'price', 'msrp', 'model_year', 'make',
#        'model', 'series', 'style', 'certified', 'has_leather',
#        'exterior_color_category', 'interior_color_category',
#        'wheelbase_from_vin', 'drivetrain_from_vin', 'engine_from_vin',
#        'transmission_from_vin', 'fuel_type_from_vin', 'number_price_changes',
#        'price_history_delimited', 'location_score', 'listing_dropoff_date'],
#       dtype='object')

# %%
df.shape
# Out:
# (145114, 31)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# listing_id                     0
# listing_type                   0
# listing_first_date             0
# days_on_market                 0
# dealer_id                      0
# dealer_city                    0
# dealer_postal_code             0
# stock_type                     0
# vehicle_id                     0
# vin                            0
# mileage                        0
# price                          0
# msrp                           0
# model_year                     0
# make                           0
# model                          0
# series                       825
# style                          0
# certified                      0
# has_leather                    0
# exterior_color_category    34947
# interior_color_category    58781
# wheelbase_from_vin             0
# drivetrain_from_vin            0
# engine_from_vin                0
# transmission_from_vin          0
# fuel_type_from_vin             0
# number_price_changes           0
# price_history_delimited        0
# location_score                 0
# listing_dropoff_date       46984
# dtype: int64

# %%
df_active = df[df['listing_type'] == 'Active']
df_sold = df[df['listing_type'] == 'Sold']

# %%
df_active.dtypes
# Out:
# listing_id                  object
# listing_type                object
# listing_first_date          object
# days_on_market               int64
# dealer_id                    int64
# dealer_city                 object
# dealer_postal_code          object
# stock_type                  object
# vehicle_id                   int64
# vin                         object
# mileage                      int64
# price                        int64
# msrp                         int64
# model_year                   int64
# make                        object
# model                       object
# series                      object
# style                       object
# certified                    int64
# has_leather                  int64
# exterior_color_category     object
# interior_color_category     object
# wheelbase_from_vin         float64
# drivetrain_from_vin         object
# engine_from_vin             object
# transmission_from_vin       object
# fuel_type_from_vin          object
# number_price_changes         int64
# price_history_delimited     object
# location_score               int64
# listing_dropoff_date        object
# dtype: object

# %%
df_active_new = df_active[df_active['stock_type'] == 'NEW']
df_active_used = df_active[df_active['stock_type'] == 'USED']

# %%
df_active_new.dtypes
# Out:
# listing_id                  object
# listing_type                object
# listing_first_date          object
# days_on_market               int64
# dealer_id                    int64
# dealer_city                 object
# dealer_postal_code          object
# stock_type                  object
# vehicle_id                   int64
# vin                         object
# mileage                      int64
# price                        int64
# msrp                         int64
# model_year                   int64
# make                        object
# model                       object
# series                      object
# style                       object
# certified                    int64
# has_leather                  int64
# exterior_color_category     object
# interior_color_category     object
# wheelbase_from_vin         float64
# drivetrain_from_vin         object
# engine_from_vin             object
# transmission_from_vin       object
# fuel_type_from_vin          object
# number_price_changes         int64
# price_history_delimited     object
# location_score               int64
# listing_dropoff_date        object
# dtype: object

# %%
df_active.shape
# Out:
# (46984, 31)

# %%
df_active['listing_dropoff_date'].isnull().sum()
# Out:
# 46984

# %%
df_sold.shape
# Out:
# (98130, 31)

# %%
df_sold['listing_dropoff_date'].isnull().sum()
# Out:
# 0

# %%
df_active = df_active.drop('listing_dropoff_date',axis = 1)

# %%
df_active.shape
# Out:
# (46984, 30)

# %%
df_sold.shape
# Out:
# (98130, 31)

# %%
df_active.sample(5)
# Out:
#                                   listing_id listing_type listing_first_date  \
# 106869  3c82f123-e76a-4359-850b-21a0bc12d863       Active     7/16/2024 0:00
# 8327    f6721376-4896-11ef-8faf-b556c2cde93f       Active     7/22/2024 0:00
# 143671  7af3f96c-7f82-4b72-969d-ea04aabc45a8       Active     7/16/2024 0:00
# 126449  268104ff-a007-468d-816e-a014b2a3523d       Active     7/16/2024 0:00
# 18229   efd2b414-b325-426e-a9c4-f34a5d5ac292       Active     7/16/2024 0:00
#
#         days_on_market  dealer_id dealer_city dealer_postal_code stock_type  \
# 106869              15   11245041   St Albert            T8N 2Y3        NEW
# 8327                 9   11236232     Acheson            T7X 5A3       USED
# 143671              15   11245093    Edmonton            T5S 1N9        NEW
# 126449              15   11244933    Edmonton            T5V 0C3        NEW
# 18229               15   11244933    Edmonton            T5V 0C3       USED
#
#         vehicle_id                vin  ...  exterior_color_category  \
# 106869      581421  3GTUUFEL9RG388429  ...                     gray
# 8327        333477  3C4PDCAB6FT700105  ...                    black
# 143671      582464  3VVLX7B21RM100331  ...                     blue
# 126449      582434  4JGGM5DBXRA048488  ...                    green
# 18229       393402  4JGDA6EB7HA956525  ...                      NaN
#
#         interior_color_category  wheelbase_from_vin  drivetrain_from_vin  \
# 106869                      NaN              3748.0                  4WD
# 8327                      black              2890.0                  FWD
# 143671         gray,brown,black              2680.0                  AWD
# 126449                      NaN              3030.0                  AWD
# 18229                     black              2915.0                  AWD
#
#               engine_from_vin transmission_from_vin fuel_type_from_vin  \
# 106869        6.2L V8 DI OHV                      A                Gas
# 8327       2.4L I-4 SFI DOHC                      A                Gas
# 143671  1.5L I-4 DI DOHC T/C                      A                Gas
# 126449          90.6kWh ELEC                      A           Electric
# 18229   3.0L V6 DI DOHC 2-T/C                     A                Gas
#
#        number_price_changes  \
# 106869                    2
# 8327                      0
# 143671                    0
# 126449                    1
# 18229                     1
#
#                                   price_history_delimited  location_score
# 106869  2024-07-16,103331,10:2024-07-18,95184,10:2024-...               5
# 8327                              2024-07-22,12995,143999               5
# 143671                                     2024-07-16,0,0               5
# 126449          2024-07-16,160597,90:2024-07-19,160675,90               5
# 18229     2024-07-16,37598,116385:2024-07-20,37098,116385               5
#
# [5 rows x 30 columns]
