# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("Go_Auto_Dataset.csv")

# %%
df['fuel_type_from_vin'].unique()
# Out:
# array(['Gas', 'CNG', 'Diesel', 'Hybrid', 'Electric', 'PHEV', 'Hydrogen'],
#       dtype=object)

# %%
df.head()
# Out:
#                              listing_id  ... listing_dropoff_date
# 0  f5b663d2-4896-11ef-a15b-8b4423f1ff08  ...                  NaN
# 1  a9f565e6-4712-11ef-a23f-79dc25c5e601  ...       7/24/2024 0:00
# 2  03d18c58-253a-11ef-8f33-8905b4a2f000  ...                  NaN
# 3  2d12630b-460e-11ee-89c4-e5b3161d4741  ...                  NaN
# 4  53a8e550-47cd-11ef-8587-f926ecb61035  ...                  NaN
#
# [5 rows x 46 columns]

# %%
df.isnull().sum()
# Out:
# listing_id                      0
# listing_heading              4015
# listing_type                    0
# listing_url                     0
# listing_first_date              0
# days_on_market                  0
# dealer_id                       0
# dealer_name                     0
# dealer_street                   0
# dealer_city                     0
# dealer_province                 0
# dealer_postal_code              0
# dealer_url                      0
# dealer_email               145114
# dealer_phone                38770
# dealer_type                     0
# stock_type                      0
# vehicle_id                      0
# vin                             0
# uvc                             0
# mileage                         0
# price                           0
# msrp                            0
# model_year                      0
# make                            0
# model                           0
# series                        825
# ...

# %%
df = df.drop('dealer_email', axis = 1)

# %%
df.isnull().sum()
# Out:
# listing_id                     0
# listing_heading             4015
# listing_type                   0
# listing_url                    0
# listing_first_date             0
# days_on_market                 0
# dealer_id                      0
# dealer_name                    0
# dealer_street                  0
# dealer_city                    0
# dealer_province                0
# dealer_postal_code             0
# dealer_url                     0
# dealer_phone               38770
# dealer_type                    0
# stock_type                     0
# vehicle_id                     0
# vin                            0
# uvc                            0
# mileage                        0
# price                          0
# msrp                           0
# model_year                     0
# make                           0
# model                          0
# series                       825
# style                          0
# certified                      0
# ...

# %%
df.shape
# Out:
# (145114, 45)

# %%
df.columns
# Out:
# Index(['listing_id', 'listing_heading', 'listing_type', 'listing_url',
#        'listing_first_date', 'days_on_market', 'dealer_id', 'dealer_name',
#        'dealer_street', 'dealer_city', 'dealer_province', 'dealer_postal_code',
#        'dealer_url', 'dealer_phone', 'dealer_type', 'stock_type', 'vehicle_id',
#        'vin', 'uvc', 'mileage', 'price', 'msrp', 'model_year', 'make', 'model',
#        'series', 'style', 'certified', 'has_leather', 'has_navigation',
#        'exterior_color', 'exterior_color_category', 'interior_color',
#        'interior_color_category', 'price_analysis', 'wheelbase_from_vin',
#        'drivetrain_from_vin', 'engine_from_vin', 'transmission_from_vin',
#        'fuel_type_from_vin', 'number_price_changes', 'price_history_delimited',
#        'distance_to_dealer', 'location_score', 'listing_dropoff_date'],
#       dtype='object')

# %%
new_df = df[['listing_type','model_year', 'make', 'model',
       'series', 'style', 'certified', 'has_leather', 'has_navigation',
       'exterior_color', 'exterior_color_category', 'interior_color',
       'interior_color_category','drivetrain_from_vin', 'engine_from_vin', 'transmission_from_vin',
       'fuel_type_from_vin']]

# %%
new_df
# Out:
#        listing_type  model_year       make         model             series  \
# 0            Active        1987  Chevrolet        Camaro           Iroc Z28
# 1              Sold        1988   Chrysler  Fifth Avenue                NaN
# 2            Active        1989   Cadillac       DeVille                NaN
# 3            Active        1989   Cadillac       DeVille                NaN
# 4            Active        1989  Chevrolet        Camaro                Z28
# ...             ...         ...        ...           ...                ...
# 145109         Sold        2024      Volvo          XC90  Recharge Ultimate
# 145110         Sold        2024      Volvo          XC90  Recharge Ultimate
# 145111         Sold        2024      Volvo          XC90  Recharge Ultimate
# 145112         Sold        2024      Volvo          XC90  Recharge Ultimate
# 145113         Sold        2024      Volvo          XC90  Recharge Ultimate
#
# ...

# %%
X = new_df.values

# %%
y = df['listing_heading']

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
# array([['Active', 2024, 'Jeep', ..., '2.0L I-4 DI DOHC T/C ', 'A', 'Gas'],
#        ['Sold', 2024, 'Mercedes-Benz', ..., '2.0L I-4 DI DOHC T/C ', 'A',
#         'Gas'],
#        ['Active', 2020, 'Kia', ..., '1.6L I-4 MPI DOHC ', 'M', 'Gas'],
#        ...,
#        ['Sold', 2023, 'Toyota', ..., '2.5L I-4 DI DOHC Hybrid ', 'A',
#         'Hybrid'],
#        ['Sold', 2014, 'Hyundai', ..., '2.0L I-4 DI DOHC CVVT', 'M',
#         'Gas'],
#        ['Sold', 2023, 'Chevrolet', ..., '3.6L V6 DI DOHC VVT', 'A',
#         'Gas']], dtype=object)

# %%
knn = KNNImputer()
X_train_trf = knn. fit_transform(X_train)
X_test_trf = knn. transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-acaa77f1fd10> in <cell line: 0>()
#       1 knn = KNNImputer()
# ----> 2 X_train_trf = knn. fit_transform(X_train)
#       3 X_test_trf = knn. transform(X_test)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# --> 918             return self.fit(X, **fit_params).transform(X)
# ...
